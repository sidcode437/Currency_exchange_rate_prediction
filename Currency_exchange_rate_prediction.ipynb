# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("INR.csv")
print(data.head())
# Out:
#          Date    Open    High     Low   Close  Adj Close  Volume Unnamed: 7
# 0  2022-01-03  74.463  74.484  74.244  74.463     74.463       0     -0.13%
# 1    4-Jan-22  74.385  74.712  74.375  74.385     74.385       0      0.17%
# 2    5-Jan-22  74.545  74.622  74.253  74.545     74.545       0     -0.30%
# 3    6-Jan-22  74.457  74.522  74.325  74.457     74.457       0      0.13%
# 4    7-Jan-22  74.457  74.457  74.245  74.457     74.457       0     -0.15%
# C:\Users\daksh\AppData\Local\Temp\ipykernel_17152\658159230.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
print(data.corr())
sns.heatmap(data.corr())
plt.show()
# Out:
#                Open      High       Low     Close  Adj Close  Volume
# Open       1.000000  0.997746  0.998538  1.000000   1.000000     NaN
# High       0.997746  1.000000  0.997957  0.997746   0.997746     NaN
# Low        0.998538  0.997957  1.000000  0.998538   0.998538     NaN
# Close      1.000000  0.997746  0.998538  1.000000   1.000000     NaN
# Adj Close  1.000000  0.997746  0.998538  1.000000   1.000000     NaN
# Volume          NaN       NaN       NaN       NaN        NaN     NaN
# C:\Users\daksh\AppData\Local\Temp\ipykernel_17152\870946064.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data.corr())
# C:\Users\daksh\AppData\Local\Temp\ipykernel_17152\870946064.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())

# %%
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0          75.630
# 1          79.255
# 2          81.460
# 3          79.710
# 4          82.775
